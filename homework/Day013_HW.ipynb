# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
import requests
import re
import pandas as pd
from bs4 import BeautifulSoup

# %%
url1 = 'https://www.ptt.cc/bbs/NBA/index.html'
url2 = 'https://www.ptt.cc/bbs/NBA/index1.html'

r = requests.get(url1)

soup = BeautifulSoup(r.text, "html5lib")

columns = ['作者', '看板', '標題', '時間']

# %%
items = soup.findAll(True, {"class": re.compile(r'(r-ent|r-list-sep)')})
for item in range(len(items)):
    if 'r-list-sep' in items[item].attrs['class']:
        try:
            r = BeautifulSoup(requests.get('https://www.ptt.cc'+items[item-1].a['href']).text, "html5lib")
            article = []
            for info in r.find_all(class_='article-meta-value'):
                article.append(info.text)
            print('作者: {}\n標題: {}\n時間: {}'.format(article[0], article[2], article[-1]))
        except:
            continue
# Out:
# 作者: blue999 (FLY)
# 標題: [花邊]林書豪被看破手腳?中媒:CBA生存比NBA更難
# 時間: Sun Dec 15 15:22:08 2019

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
def GetFistPageInfo(url):
    r = requests.get(url)
    
    soup = BeautifulSoup(r.text, "html5lib")
    
    articles = []
    
    for d in soup.find_all(class_="title"):
        try:
            r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
            article = []
            for info in r.find_all(class_='article-meta-value'):
                article.append(info.text)
            articles.append(article)
        except:
            continue
    df = pd.DataFrame(articles, columns=columns)
    
    return df

# %%
GetFistPageInfo(url2)
# Out:
#                              作者   看板                         標題  \
# 0                 Price (Price)  NBA    [轉錄]Lyotard 對於太陽板討論串的結論
# 1                 Price (Price)  NBA        [公告] 請停止一切關於本次活動的發言
# 2               Frankaze (神采風華)  NBA   [轉錄]跟之前那篇比起來 我覺得這篇也應該轉過來
# 3               Frankaze (神采風華)  NBA                [轉錄]再轉一篇好文來
# 4                 Price (Price)  NBA           [轉錄][情報] 夏洛特山貓系列
# 5                 Price (Price)  NBA   [轉錄]Re: [心得] 真是受不了糗爺....
# 6                 Price (Price)  NBA            [轉錄]總冠軍賽NO.2觀後感
# 7   AmuroNamie (原來太嗨真的會失眠^___^)  NBA       [心得] Rasheed Wallace
# 8                  toptree (  )  NBA                    掌控球賽的男人
# 9            skchang (3EB板開板囉！)  NBA        [閒聊] 說說2004季後賽名場面回顧
# 10                   shineup ()  NBA     [心得] 其實說穿了 就是活塞的防守太可怕了
# 11                    cOvi (喵~)  NBA    Re: [閒聊] 說說2004季後賽名場面回顧
# 12               ykshih (￼N￼Ns)  NBA    Re: [閒聊] 說說2004季後賽名場面回顧
# 13              Frankaze (神采風華)  NBA    Re: [閒聊] 說說2004季後賽名場面回顧
# 14                Price (Price)  NBA        [轉錄]Re: 總冠軍賽NO.3觀後感
# 15              Frankaze (神采風華)  NBA        [轉錄]Re: 總冠軍賽NO.3觀後感
# 16          star1 (第一次魔術表演不算成功)  NBA    Re: [轉錄]Re: 總冠軍賽NO.3觀後感
# 17              coldspring (笑笑)  NBA    Re: [轉錄]Re: 總冠軍賽NO.3觀後感
# 18                 airbear (地圖)  NBA  Re: Kobe is frustrated...
# 19            pennykidd (andre)  NBA    Re: [轉錄]Re: 總冠軍賽NO.3觀後感
#
#                           時間
# 0   Sun May 16 01:54:33 2004
# 1   Mon May 24 00:43:00 2004
# 2   Tue Jun  8 01:16:45 2004
# 3   Tue Jun  8 09:02:23 2004
# 4   Thu Jun 10 00:39:35 2004
# 5   Thu Jun 10 00:51:35 2004
# 6   Thu Jun 10 12:05:07 2004
# 7   Fri Jun 11 15:06:09 2004
# 8   Sat Jun 12 07:13:04 2004
# 9   Sat Jun 12 13:21:49 2004
# 10  Sat Jun 12 13:12:47 2004
# 11  Sat Jun 12 16:43:07 2004
# 12  Sat Jun 12 17:26:37 2004
# 13  Sat Jun 12 18:34:46 2004
# 14  Mon Jun 14 02:18:52 2004
# 15  Mon Jun 14 02:34:33 2004
# 16  Mon Jun 14 07:16:30 2004
# 17  Mon Jun 14 09:24:57 2004
# 18  Mon Jun 14 12:56:14 2004
# 19  Mon Jun 14 22:07:01 2004

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
GetFistPageInfo('https://www.ptt.cc/bbs/TaiwanDrama/index1.html')
# Out:
#                        作者           看板                          標題  \
# 0         angelvic (潛水ㄉ熊)  TaiwanDrama        韓劇「亂倫」殺無赦 台劇「亂愛」超複雜
# 1           ghty (聖披頭堡堡主)  TaiwanDrama                  偶像劇 就是這樣發酵
# 2           ghty (聖披頭堡堡主)  TaiwanDrama                廣告插花 偶像劇處處商機
# 3           ghty (聖披頭堡堡主)  TaiwanDrama            七年級星勢力》一片偶像 自然消失
# 4      angelvic (牛奶色ζ小熊ζ)  TaiwanDrama               八點檔看偶像 小燕姐讓一邊
# 5          silvia6 (零度寂寞)  TaiwanDrama               Re: [討論] 極速青春
# 6           ghty (聖披頭堡堡主)  TaiwanDrama                  開學了 偶像劇冷颼颼
# 7           ghty (聖披頭堡堡主)  TaiwanDrama               八點檔好賺 藝人軋戲不軋命
# 8         sachet (柳橙girl)  TaiwanDrama        Re: 黑 請問一下有沒有人看書劍恩仇錄
# 9           ghty (聖披頭堡堡主)  TaiwanDrama            螢幕Lover 玩火就Over？
# 10  angelvic (       ＊熊＊)  TaiwanDrama           流星花園Ⅱ》流Ⅱ結局 F4自編自笑
# 11  angelvic (       ＊熊＊)  TaiwanDrama             流星花園Ⅱ》言承旭版 悲情極致
# 12  angelvic (       ＊熊＊)  TaiwanDrama             流星花園Ⅱ》周渝民版 浪漫離奇
# 13  angelvic (       ＊熊＊)  TaiwanDrama              流星花園Ⅱ》朱孝天版 花系列
# 14  angelvic (       ＊熊＊)  TaiwanDrama             流星花園Ⅱ》吳建豪版 科幻驚奇
# 15  angelvic (       ＊熊＊)  TaiwanDrama             流星花園Ⅱ》F4劇中豪宅比一比
# 16  angelvic ( Over Time)  TaiwanDrama  Re: [問題] 請問一下 星期一和星期二的流星花園
# 17  silvia6 (搖滾本事12/20上映)  TaiwanDrama        Re: [問題] 拜託 我真的很想要知道
# 18  silvia6 (搖滾本事12/20上映)  TaiwanDrama        Re: [問題] 拜託 我真的很想要知道
# 19  angelvic ( Over Time)  TaiwanDrama                 聖夏零度Ｃ　故事大綱
#
#                           時間
# 0   Wed May 15 10:53:49 2002
# 1   Mon May 20 10:31:41 2002
# 2   Fri May 31 15:03:24 2002
# 3   Thu Jun  6 09:01:10 2002
# 4   Mon Aug  5 17:24:56 2002
# 5   Mon Aug  5 23:09:15 2002
# 6   Thu Sep  5 13:45:26 2002
# 7   Mon Sep  9 15:48:47 2002
# 8   Fri Sep 13 12:47:26 2002
# 9   Tue Oct  1 15:22:16 2002
# 10  Tue Nov 12 21:33:06 2002
# 11  Tue Nov 12 21:33:25 2002
# 12  Tue Nov 12 21:33:50 2002
# 13  Tue Nov 12 21:34:06 2002
# 14  Tue Nov 12 21:34:29 2002
# 15  Tue Nov 12 21:36:32 2002
# 16  Wed Dec  4 21:56:44 2002
# 17  Fri Dec 13 17:45:58 2002
# 18  Sat Dec 14 10:02:29 2002
# 19  Thu Dec 19 21:26:41 2002
